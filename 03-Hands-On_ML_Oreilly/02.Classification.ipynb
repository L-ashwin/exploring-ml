# %% [markdown]
# # Load the Dataset

# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1)
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
x_data, y_data = mnist['data'], mnist['target']

# %%
print('shape of x_data:',x_data.shape)
print('shape of y_data:',y_data.shape)
# Out:
# shape of x_data: (70000, 784)
# shape of y_data: (70000,)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(x_data[0].reshape(28,28), cmap='binary')
plt.axis('off')
plt.show()

# %%
# mnist data is already split into test and train; first 60k examples are train and rest test
x_train, x_test, y_train, y_test = x_data[:60000], x_data[60000:], y_data[:60000], y_data[60000:]
